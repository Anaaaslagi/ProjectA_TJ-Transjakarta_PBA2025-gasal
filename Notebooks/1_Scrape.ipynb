# %% [markdown]
# # Web Scraping Artikel Berita Transjakarta
#
# ## Instalasi library yang dibutuhkan (cukup jalankan sekali)
# ## Pastikan Anda menjalankan ini di terminal atau command prompt:
# ## pip install pandas requests beautifulsoup4

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import os

# %%
# --- 1. Membaca File CSV ---
csv_path = '../Data/Kelompok2_Artikel_TransJakarta - Artikel Berita.csv'

# %%
if not os.path.exists(csv_path):
    print("Error: File tidak ditemukan.")
else:
    print("File CSV berhasil ditemukan. Memulai proses scraping...")
    df = pd.read_csv(csv_path)

    # --- 2. Fungsi Scraping ---
    def scrape_article(url):
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        try:
            response = requests.get(url, headers=headers, timeout=15)
            if response.status_code != 200:
                return "Gagal", f"Status Code: {response.status_code}", "request_gagal"

            soup = BeautifulSoup(response.content, 'html.parser')
            title = "Judul tidak ditemukan"
            content = "Konten tidak ditemukan"

            # Logika untuk setiap sumber berita
            if any(domain in url for domain in ['news.detik.com', 'oto.detik.com', 'finance.detik.com', 'travel.detik.com']):
                title_tag = soup.find('h1', class_='detail__title')
                article_body = soup.find('div', class_='detail__body-text')
                if title_tag: title = title_tag.get_text(strip=True)
                if article_body:
                    paragraphs = article_body.find_all('p')
                    content = "\n".join([p.get_text(strip=True) for p in paragraphs])

            elif 'kompas.id' in url:
                title_tag = soup.find('h1', class_='title-read')
                article_body = soup.find('div', class_='paywall')
                if title_tag: title = title_tag.get_text(strip=True)
                if article_body:
                    paragraphs = article_body.find_all('p')
                    content = "\n".join([p.get_text(strip=True) for p in paragraphs])

            elif 'liputan6.com' in url:
                # Coba cari judul dengan class pertama
                title_tag = soup.find('h1', class_='article-header__title')
                if not title_tag: # Jika tidak ketemu, coba class kedua
                    title_tag = soup.find('h1', class_='read-page--header--title')
                if title_tag: title = title_tag.get_text(strip=True)

                # Coba cari konten dengan class pertama
                article_body = soup.find('div', class_='article-body__content-aside')
                if not article_body: # Jika tidak ketemu, coba class kedua
                    article_body = soup.find('div', class_='read-page--content')
                
                if article_body:
                    for unwanted_div in article_body.find_all('div', class_='baca-juga'):
                        unwanted_div.decompose()
                    paragraphs = article_body.find_all('p')
                    content = "\n".join([p.get_text(strip=True) for p in paragraphs if p.get_text(strip=True)])
            
            elif 'tempo.co' in url:
                title_tag = soup.find('h1', itemprop='headline')
                article_body = soup.find('div', itemprop='articleBody')
                if title_tag: title = title_tag.get_text(strip=True)
                if article_body:
                    paragraphs = article_body.find_all('p')
                    content = "\n".join([p.get_text(strip=True) for p in paragraphs])

            elif 'cnnindonesia.com' in url:
                title_tag = soup.find('h1', class_='text-cnn_black')
                article_body = soup.find('div', class_='detail-text')
                if title_tag: title = title_tag.get_text(strip=True)
                if article_body:
                    # Hapus transkrip video jika ada
                    for transcript in article_body.find_all('div', class_='transcript-box'):
                        transcript.decompose()
                    paragraphs = article_body.find_all('p')
                    content = "\n".join([p.get_text(strip=True) for p in paragraphs])

            # Membersihkan sisa teks promosi
            if "Baca juga:" in content:
                content = content.split("Baca juga:")[0]
            if "Simak video" in content:
                content = content.split("Simak video")[0]

            return title, content.strip(), "success"

        except requests.RequestException as e:
            return "Gagal", f"Error Koneksi: {e}", "koneksi_gagal"
        except Exception as e:
            return "Gagal", f"Error Lainnya: {e}", "exception"

    # --- 3. Proses Scraping Seluruh Link ---
    results = []
    total_links = len(df)
    for index, row in df.iterrows():
        link = row['Link']
        if pd.notna(link) and link.startswith('http'):
            print(f"Scraping ({index + 1}/{total_links}): {link}")
            judul, isi_berita, status = scrape_article(link)
            results.append({'Judul': judul, 'Isi Berita': isi_berita, 'Status': status})
            time.sleep(1) # Jeda 0.5 detik
        else:
            results.append({'Judul': 'Tidak ada link', 'Isi Berita': '', 'Status': 'link_kosong'})

    # --- 4. Menggabungkan Hasil dan Menyimpan File ---
    df_hasil = pd.DataFrame(results)
    df_final = pd.concat([df.reset_index(drop=True), df_hasil], axis=1)

    output_path = '../Data/hasil_scraping_transjakarta.csv'
    df_final.to_csv(output_path, index=False, encoding='utf-8', sep=';')

    print(f"\n✅ Proses scraping selesai. Hasil disimpan di file: {output_path}")
    print("\nCuplikan 5 baris pertama dari data hasil scraping:")
    print(df_final[['Link', 'Judul', 'Status']].head())

    # Cek jumlah scraping yang berhasil vs gagal
    sukses_count = df_final[df_final['Status'] == 'success'].shape[0]
    gagal_count = total_links - sukses_count
    print(f"Total link: {total_links} | Berhasil: {sukses_count} | Gagal: {gagal_count}")
# Out:
# File CSV berhasil ditemukan. Memulai proses scraping...
# Scraping (1/150): https://news.detik.com/berita/d-8114173/hore-naik-transjakarta-mrt-lrt-jakarta-rp-1-di-17-19-september
# Scraping (2/150): https://news.detik.com/berita/d-8084934/sejumlah-layanan-transjakarta-terganggu-imbas-demo-ini-daftar-rute-yang-dialihkan
# Scraping (3/150): https://news.detik.com/berita/d-8108095/truk-mogok-di-jalan-gatsu-arah-cawang-sejumlah-rute-transj-terganggu
# Scraping (4/150): https://news.detik.com/berita/d-8018912/rano-karno-rute-transjakarta-ancol-blok-m-akan-meluncur-agustus
# Scraping (5/150): https://oto.detik.com/berita/d-8127426/bus-listrik-transjakarta-kecelakaan-di-setiabudi-bukan-karena-rem-blong
# Scraping (6/150): https://news.detik.com/berita/d-8099155/transjakarta-investigasi-internal-usai-bus-seruduk-warung-di-jaksel
# Scraping (7/150): https://news.detik.com/berita/d-8125150/investigasi-3-kali-kecelakaan-bus-dalam-sebulan-transj-gandeng-knkt
# Scraping (8/150): https://news.detik.com/berita/d-8058951/mereka-menjerit-berjam-jam-antre-di-transj-jalur-langit
# Scraping (9/150): https://news.detik.com/berita/d-8118174/kecelakaan-truk-vs-transj-di-cideng-jakpus-sopir-luka
# Scraping (10/150): https://news.detik.com/berita/d-8074906/motor-tersangkut-di-kolong-bus-transjakarta-di-plumpang-jakut
# Scraping (11/150): https://news.detik.com/berita/d-8123596/nasdem-dorong-evaluasi-transj-imbas-kecelakaan-demi-keselamatan-banyak-orang
# Scraping (12/150): https://news.detik.com/berita/d-8086709/seluruh-layanan-transjakarta-disetop-sementara-malam-ini
# Scraping (13/150): https://news.detik.com/berita/d-8086780/total-3-halte-transjakarta-rusak-dan-terbakar-malam-ini
# Scraping (14/150): https://news.detik.com/berita/d-8026782/kabar-gembira-rute-transjakarta-blok-m-ancol-diluncurkan-sabtu-ini
# Scraping (15/150): https://news.detik.com/berita/d-7944954/transj-sempat-lerai-kakek-teriaki-penumpang-teroris-tapi-pelaku-marah
# Scraping (16/150): https://news.detik.com/berita/d-8040077/asyik-tarif-transjakarta-mrt-hingga-krl-rp-80-pada-17-agustus
# Scraping (17/150): https://news.detik.com/berita/d-8009255/beli-tiket-transjakarta-bisa-pakai-tjpay-ini-cara-aktivasinya
# Scraping (18/150): https://news.detik.com/berita/d-8062434/begini-solusi-pemprov-dki-cegah-separator-transj-koridor-9-ditabrak-lagi
# Scraping (19/150): https://news.detik.com/berita/d-7958648/penampakan-puluhan-bus-bekas-transj-ludes-terbakar-di-terminal-rawa-buaya
# Scraping (20/150): https://finance.detik.com/infrastruktur/d-8046529/rute-transjakarta-mau-diperluas-bisa-masuk-pelabuhan-tanjung-priok
# Scraping (21/150): https://news.detik.com/berita/d-8007885/transjakarta-tanam-15-000-mangrove-libatkan-masyarakat-dan-mitra
# Scraping (22/150): https://news.detik.com/berita/d-7963284/ada-lps-monas-half-marathon-15-juni-sejumlah-rute-transjakarta-disesuaikan
# Scraping (23/150): https://news.detik.com/berita/d-8003883/transjakarta-ajak-mitra-operator-evaluasi-layanan-secara-langsung
# Scraping (24/150): https://news.detik.com/berita/d-8005378/transjakarta-manfaatkan-teknologi-ai-untuk-optimalkan-pelayanan-pelanggan
# Scraping (25/150): https://news.detik.com/berita/d-7934163/pramono-mau-bikin-30-bus-transjakarta-bernuansa-persija
# Scraping (26/150): https://news.detik.com/berita/d-8024670/tj-rute-blok-m-ancol-dan-70-bus-listrik-high-deck-bakal-diluncurkan-bulan-ini
# Scraping (27/150): https://news.detik.com/berita/d-8000521/transjakarta-lapor-polisi-buntut-sopir-dipukul-ojol-di-jakbar
# Scraping (28/150): https://news.detik.com/berita/d-7950149/pramono-targetkan-2-000-bus-listrik-transjakarta-pada-2029
# Scraping (29/150): https://news.detik.com/berita/d-7993872/cek-di-sini-rute-transjakarta-bekasi-dukuh-atas-via-tol-becakayu
# Scraping (30/150): https://news.detik.com/berita/d-7903411/resmi-15-golongan-ini-gratis-naik-transjakarta-mrt-dan-lrt
# Scraping (31/150): https://news.detik.com/berita/d-7916140/transjakarta-cares-untuk-penyandang-disabilitas-jam-layanan-dan-cara-pesan
# Scraping (32/150): https://news.detik.com/berita/d-7874250/rute-transjakarta-arah-tanjung-priok-diperpendek-imbas-antrean-bongkar-muat
# Scraping (33/150): https://news.detik.com/berita/d-8051736/gagal-nyalip-pemotor-tewas-terlindas-transj-di-jakbar
# Scraping (34/150): https://news.detik.com/berita/d-8006088/transjakarta-bantu-24-000-bibit-kerapu-untuk-nelayan-di-kepulauan-seribu
# Scraping (35/150): https://finance.detik.com/berita-ekonomi-bisnis/d-8038123/permudah-pelanggan-gopay-jadi-metode-pembayaran-di-aplikasi-transjakarta
# Scraping (36/150): https://news.detik.com/berita/d-7895470/gerindra-dki-tak-masalah-tarif-transjakarta-naik-asalkan-publik-sanggup
# Scraping (37/150): https://news.detik.com/berita/d-7765873/pengguna-transj-naik-2-kali-lipat-tahun-2024-subsidi-tiap-penumpang-rp-9-831
# Scraping (38/150): https://news.detik.com/berita/d-7978546/lewat-program-berdaya-transjakarta-beri-kesempatan-magang-jadi-pramusapa
# Scraping (39/150): https://news.detik.com/berita/d-7983691/transjakarta-raih-penghargaan-sebagai-perusahaan-dengan-gcg-terbaik
# Scraping (40/150): https://news.detik.com/berita/d-8146114/transjakarta-tambah-151-armada-antisipasi-lonjakan-hut-ke-80-tni-di-monas
# Scraping (41/150): https://news.detik.com/berita/d-8133205/arti-kode-rute-layanan-transjakarta-simak-penjelasannya-di-sini
# Scraping (42/150): https://oto.detik.com/mobil-listrik/d-7668485/sinar-jaya-suplai-bus-listrik-buat-transjakarta-bodi-laksana-sasis-vktr
# Scraping (43/150): https://finance.detik.com/moneter/d-7824100/naik-mrt-dan-transjakarta-bisa-pakai-qris-tap-di-aplikasi-ini
# Scraping (44/150): https://travel.detik.com/travel-news/d-7630337/strategi-jitu-transjakarta-bikin-pengendara-mobil-pindah-ke-transportasi-umum
# Scraping (45/150): https://oto.detik.com/berita/d-7641477/geger-aksi-gila-pemotor-lempar-batu-ke-bus-tj-ternyata-ini-motifnya
# Scraping (46/150): https://finance.detik.com/energi/d-7538684/transjakarta-setop-pengadaan-bus-solar-mau-tambah-200-bus-listrik
# Scraping (47/150): https://news.detik.com/berita/d-8141041/langkah-transjakarta-usai-skywalk-kebayoran-lama-banyak-kotoran-kucing
# Scraping (48/150): https://news.detik.com/berita/d-8140278/penumpang-transj-menumpuk-di-halte-tegal-mampang-ini-penyebabnya
# Scraping (49/150): https://news.detik.com/berita/d-7876881/perempuan-gratis-naik-transj-mrt-lrt-di-hari-kartini-gate-khusus-disiapkan
# Scraping (50/150): https://news.detik.com/berita/d-8079277/anggota-dprd-dki-dukung-transjakarta-di-rute-tb-simatupang-ditambah
# Scraping (51/150): https://www.kompas.id/artikel/pro-kontra-pengguna-transjakarta-di-seputar-wacana-kenaikan-tarif
# Scraping (52/150): https://www.kompas.id/artikel/transjakarta-buka-sekolah-pramudi-jamin-kompetensi-dan-cegah-kecelakaan?open_from=Search_Result_Page
# Scraping (53/150): https://www.kompas.id/artikel/transjakarta-akan-tambah-rute-di-bodetabek?open_from=Search_Result_Page
# Scraping (54/150): https://www.kompas.id/artikel/transjakarta-dan-mrt-jakarta-beririsan-tetapi-saling-melengkapi?open_from=Search_Result_Page
# Scraping (55/150): https://www.kompas.id/artikel/transjakarta-tambah-200-unit-bus-listrik?open_from=Search_Result_Page
# Scraping (56/150): https://www.kompas.id/artikel/transjakarta-perluas-rute-untuk-jangkau-seluruh-pasar-di-jakarta
# Scraping (57/150): https://www.kompas.id/artikel/sempat-didemo-sopir-angkot-transjakarta-rute-10m-kembali-beroprasi-akhir-maret
# Scraping (58/150): https://www.kompas.id/artikel/lamban-tanggapi-keluhan-penumpang-anggap-transjakarta-tidak-solutif
# Scraping (59/150): https://www.kompas.id/artikel/menagih-perbaikan-layanan-dan-keselamatan-transjakarta
# Scraping (60/150): https://www.kompas.id/baca/metro/2023/05/24/beroperasi-kembali-halte-dukuh-atas-2-dan-manggarai-diapresiasi-sekaligus-dikeluhkan-pengguna?open_from=Search_Result_Page
# Scraping (61/150): https://www.kompas.id/artikel/pengemudi-mikrolet-protes-penambahan-armada-transjakarta-di-stasiun-tebet
# Scraping (62/150): https://www.kompas.id/artikel/transjakarta-nol-kecelakaan
# Scraping (63/150): https://www.kompas.id/artikel/jangan-surut-transjakarta
# Scraping (64/150): https://www.kompas.id/artikel/perubahan-terminal-menyusahkan
# Scraping (65/150): https://www.kompas.id/artikel/walaupun-rusak-halte-bus-transjakarta-layani-penumpang?open_from=Search_Result_Page
# Scraping (66/150): https://www.kompas.id/artikel/halte-dibakar-transjakarta-hentikan-operasional?open_from=Search_Result_Page
# Scraping (67/150): https://www.kompas.id/artikel/seorang-pria-menganiaya-perempuan-di-dalam-bus-transjakarta?open_from=Search_Result_Page
# Scraping (68/150): https://www.tempo.co/politik/alasan-pramono-ubah-nama-halte-senen-jadi-halte-jaga-jakarta-2067649
# Scraping (69/150): https://www.tempo.co/politik/setelah-diperbaiki-halte-transjakarta-senen-sentral-berubah-nama-menjadi-jaga-jakarta-2067609
# Scraping (101/150): https://www.liputan6.com/news/read/5845416/wakil-ketua-dprd-jakarta-tolak-wacana-kenaikan-tarif-jakarta
# Scraping (102/150): https://www.liputan6.com/news/read/5982814/libur-lebaran-transjakarta-tambah-operasional-armada-ke-tempat-wisata
# Scraping (103/150): https://www.cnnindonesia.com/nasional/20230221154326-12-915899/cerita-penumpang-transjakarta-saat-alami-pelecehan-di-dalam-bus
# Scraping (104/150): https://www.liputan6.com/news/read/6009550/pramono-akui-masalah-konektivitas-transportasi-umum-masih-jadi-kendala
# Scraping (105/150): https://www.liputan6.com/news/read/6107916/transjakarta-kembangkan-3-teknologi-ai-untuk-sistem-layanan-dan-operasional
# Scraping (106/150): https://www.liputan6.com/news/read/5791201/polisi-tangkap-pria-yang-viral-lempar-kaca-bus-transjakarta-di-jaksel
# Scraping (107/150): https://www.liputan6.com/news/read/6176620/perkuat-layanan-saat-hut-tni-transjakarta-kerahkan-151-bus-tambahan
# Scraping (108/150): https://www.liputan6.com/news/read/6164948/pramono-anung-bakal-evaluasi-transjakarta-pasca-serangkaian-kecelakaan-sebulan-terakhir
# Scraping (109/150): https://www.liputan6.com/news/read/6163372/transjakarta-tabrak-kios-dan-rumah-di-cakung-6-orang-terluka
# Scraping (110/150): https://www.liputan6.com/news/read/6152606/bus-oleng-dan-tabrak-toko-di-jaksel-transjakarta-minta-maaf-dan-janji-investigasi
# Scraping (111/150): https://www.liputan6.com/bisnis/read/6148879/halte-transjakarta-yang-terbakar-siap-berfungsi-pekan-ini
# Scraping (112/150): https://www.liputan6.com/news/read/6148945/satu-pelaku-pembakar-halte-transjakarta-ditangkap-ini-identitasnya
# Scraping (113/150): https://www.liputan6.com/feeds/read/5951752/panduan-lengkap-cara-naik-transjakarta-untuk-pemula-berikut-triknya
# Scraping (114/150): https://www.liputan6.com/news/read/6141481/transjakarta-tambah-armada-dan-rute-baru-atasi-macet-horor-di-tb-simatupang-ini-daftarnya
# Scraping (115/150): https://www.liputan6.com/news/read/6117422/rute-transjakarta-dialihkan-buntut-kebakaran-pasar-taman-puring-ini-perubahannya
# Scraping (116/150): https://www.liputan6.com/news/read/6107916/transjakarta-kembangkan-3-teknologi-ai-untuk-sistem-layanan-dan-operasional
# Scraping (117/150): https://www.liputan6.com/news/read/6047842/pria-lansia-yang-teriaki-wanita-teroris-di-transjakarta-minta-maaf
# Scraping (118/150): https://www.liputan6.com/news/read/6023777/seorang-penumpang-meninggal-di-toilet-halte-transjakarta-kampung-melayu
# Scraping (119/150): https://www.liputan6.com/news/read/6000984/penumpang-sebut-transjakarta-kini-lebih-aman-tak-khawatirkan-pelecehan
# Scraping (120/150): https://www.liputan6.com/news/read/6000577/kata-penumpang-perempuan-yang-naik-transjakarta-gratis-di-hari-kartini-21-april
# Scraping (121/150): https://www.liputan6.com/bisnis/read/6146760/transjakarta-gratiskan-layanan-selama-seminggu-catat-tanggalnya
# Scraping (122/150): https://www.liputan6.com/news/read/6146213/situasi-belum-kondusif-transjakarta-hentikan-seluruh-layanan-pada-sabtu-pagi-ini
# Scraping (123/150): https://www.liputan6.com/news/read/6126435/viral-moge-masuk-jalur-transjakarta-polisi-motor-kecil-juga-banyak-melanggar-semua-kena-tilang
# Scraping (124/150): https://www.liputan6.com/otomotif/read/6119038/debut-di-giias-2025-isuzu-elf-nqr-b-siap-jadi-andalan-baru-transjakarta
# Scraping (125/150): https://www.liputan6.com/news/read/6039163/polisi-buru-penganiaya-wanita-di-halte-transjakarta-grogol-jakbar
# Scraping (126/150): https://www.liputan6.com/global/read/6020347/dubes-belanda-naik-transjakarta-dukung-inisiatif-transportasi-ramah-lingkungan-di-jakarta
# Scraping (127/150): https://www.liputan6.com/news/read/6122428/eks-jubir-kpk-johan-budi-ditunjuk-jadi-komisaris-transjakarta
# Scraping (128/150): https://www.liputan6.com/news/read/6122442/perjalanan-karir-johan-budi-eks-jubir-kpk-kini-jabat-komisaris-transjakarta
# Scraping (129/150): https://www.liputan6.com/cek-fakta/read/6131038/tarif-rp-80-untuk-transjakarta-mrt-dan-lrt-diperpanjang-jadi-2-hari
# Scraping (130/150): https://www.liputan6.com/news/read/4613642/upaya-transjakarta-sediakan-300-bus-listrik-kurangi-emisi-di-jakarta
# Scraping (131/150): https://www.liputan6.com/news/read/6144945/rute-transjakarta-koridor-9-dan-6-sebagian-dialihkan-imbas-demo-ricuh-di-dpr-berikut-pengaturannya
# Scraping (132/150): https://www.liputan6.com/news/read/6146072/kericuhan-di-polda-metro-jaya-memanas-halte-transjakarta-dibakar-massa
# Scraping (133/150): https://www.liputan6.com/bola/read/6167637/sambut-jakarta-running-festival-2025-pemprov-dki-jakarta-gratiskan-mrt-dan-transjakarta
# Scraping (134/150): https://www.liputan6.com/news/read/6146828/layanan-transjakarta-hingga-mikrotrans-berangsur-normal-ini-daftar-rute-yang-bisa-dilalui
# Scraping (135/150): https://www.liputan6.com/news/read/6146609/imbas-demo-ricuh-di-jakarta-6-halte-transjakarta-terbakar-16-lainnya-alami-vandalisme
# Scraping (136/150): https://www.liputan6.com/news/read/6146575/usai-gangguan-sistem-buntut-demo-pemprov-jakarta-gratiskan-transjakarta-hingga-mrt-selama-sepekan
# Scraping (137/150): https://www.liputan6.com/news/read/6003692/hari-angkutan-nasional-2025-naik-transjakarta-mrt-dan-lrt-jakarta-gratis
# Scraping (138/150): https://www.liputan6.com/news/read/6009252/momen-pramono-anung-bekerja-naik-transjakarta-pada-rabu-pertama
# Scraping (139/150): https://www.liputan6.com/bisnis/read/6000250/peringati-hari-kartini-21-april-transjakarta-tetapkan-tarif-rp-1-untuk-perempuan
# Scraping (140/150): https://www.liputan6.com/news/read/6043058/pria-lansia-yang-cekcok-dan-teriak-teroris-ke-penumpang-wanita-di-blacklist-transjakarta
# Scraping (141/150): https://www.liputan6.com/lifestyle/read/6057404/naik-transjakarta-krl-commuterline-hingga-mrt-cuma-rp1-di-momen-ulang-tahun-ke-498-kota-jakarta
# Scraping (142/150): https://www.liputan6.com/news/read/6090860/transjakarta-uji-coba-bus-listrik-highdeck
# Scraping (143/150): https://www.liputan6.com/news/read/6091420/ini-operasional-mrt-transjakarta-saat-btn-jakarta-international-marathon-digelar-besok
# Scraping (144/150): https://www.liputan6.com/news/read/6093793/6-fakta-perayaan-hut-bhayangkara-ke-79-di-monas-mulai-hiburan-hingga-promo-tarif-transjakarta
# Scraping (145/150): https://www.liputan6.com/news/read/6116083/rute-transjakarta-blok-mancol-resmi-dibuka-gunakan-bus-listrik-untuk-turunkan-emisi
# Scraping (146/150): https://www.liputan6.com/news/read/6027258/demo-ojol-20-mei-2025-transjakarta-alihkan-rute-sesuai-kondisi-lapangan
# Scraping (147/150): https://www.liputan6.com/news/read/6015193/bus-transjakarta-akan-melintas-di-terminal-sawangan-dan-margonda-ini-rutenya
# Scraping (148/150): https://www.liputan6.com/news/read/6134215/transjakarta-modifikasi-layanan-di-19-rute-saat-pesta-rakyat-hut-ke-80-ri
# Scraping (149/150): https://www.liputan6.com/otomotif/read/6135408/peringati-hut-ke-80-ri-desain-unik-hiasi-armada-bus-transjakarta
# Scraping (150/150): https://www.liputan6.com/news/read/6145209/info-operasional-krl-commuterline-hingga-transjakarta-hari-ini-usai-demo-28-agustus-berakhir-ricuh
#
# ✅ Proses scraping selesai. Hasil disimpan di file: ../Data/hasil_scraping_transjakarta.csv
#
# Cuplikan 5 baris pertama dari data hasil scraping:
#                                                 Link  \
# 0  https://news.detik.com/berita/d-8114173/hore-n...
# 1  https://news.detik.com/berita/d-8084934/sejuml...
# 2  https://news.detik.com/berita/d-8108095/truk-m...
# 3  https://news.detik.com/berita/d-8018912/rano-k...
# 4  https://oto.detik.com/berita/d-8127426/bus-lis...
#
#                                                Judul   Status
# 0  Hore! Naik Transjakarta, MRT, LRT Jakarta Rp 1...  success
# 1  Sejumlah Layanan Transjakarta Terganggu Imbas ...  success
# 2  Truk Mogok di Jalan Gatsu Arah Cawang, Sejumla...  success
# 3  Rano Karno: Rute TransJakarta Ancol-Blok M Aka...  success
# 4  Bus Listrik Transjakarta Kecelakaan di Setiabu...  success
# Total link: 150 | Berhasil: 114 | Gagal: 36
